# %% [markdown]
# <a href="https://colab.research.google.com/github/tyler-kom/group-14/blob/main/DTSC1302_Group14_colab_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#url to dataset on the github repo
url = "https://raw.githubusercontent.com/tyler-kom/group-14/refs/heads/main/health_insurance_dataset_group_14.csv"

df = pd.read_csv(url)
df.head(5)
# Out:
#         State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0    Alabama                  14.6%                 10.1%
# 1     Alaska                  19.9%                 14.9%
# 2    Arizona                  16.9%                 10.8%
# 3   Arkansas                  17.5%                  9.5%
# 4  California                 18.5%                  8.6%
#
#   Uninsured Rate Change (2010-2015)  \
# 0                            -4.5%
# 1                              -5%
# 2                            -6.1%
# 3                              -8%
# 4                            -9.9%
#
#    Health Insurance Coverage Change (2010-2015)  \
# 0                                        215000
# 1                                         36000
# 2                                        410000
# 3                                        234000
# 4                                       3826000
#
#    Employer Health Insurance Coverage (2015)  \
# 0                                    2545000
# ...

# %%
# !git clone https://github.com/tyler-kom/group-14
# %cd group-14
df = pd.read_csv("health_insurance_dataset_group_14.csv")
df.head(5)
# Out:
# Cloning into 'group-14'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# Receiving objects: 100% (6/6), 4.46 KiB | 4.46 MiB/s, done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# /content/group-14
#         State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0    Alabama                  14.6%                 10.1%
# 1     Alaska                  19.9%                 14.9%
# 2    Arizona                  16.9%                 10.8%
# 3   Arkansas                  17.5%                  9.5%
# 4  California                 18.5%                  8.6%
#
#   Uninsured Rate Change (2010-2015)  \
# 0                            -4.5%
# 1                              -5%
# 2                            -6.1%
# 3                              -8%
# 4                            -9.9%
#
#    Health Insurance Coverage Change (2010-2015)  \
# ...
